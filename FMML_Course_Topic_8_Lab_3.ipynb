# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhurithotakua/FMML_ALL_MODULES/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 06:51:23--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   101MB/s    in 0.7s
#
# 2024-03-26 06:51:24 (101 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 28178  1705.08620v1  Domain adaptation (DA) is transfer learning wh...    cs
# 32816  1508.02268v1  Dropout and other feature noising schemes have...    cs
# 5153    1005.0188v1  We introduce two kernels that extend the mean ...    cs
# 8537   1703.09783v1  The recognition of actions from video sequence...    cs
# 18998   1301.6704v1  Markov decisions processes (MDPs) are becoming...    cs
# ...             ...                                                ...   ...
# 39090   1307.3581v2  In this paper, a color transfer framework to e...    cs
# 22460  1608.01008v3  We study probability measures induced by set f...  stat
# 23014  1801.10579v1  Telling cause from effect using observational ...  stat
# 14548  cs/0206034v1  This paper applies an existing query translati...    cs
# 23787   1406.3949v1  Retrieving similar images from a large dataset...    cs
#
#                                                    title  year  \
# 28178  Robust Data Geometric Structure Aligned Close ...  2017
# 32816   Dropout Training for SVMs with Data Augmentation  2015
# 5153              Generative and Latent Mean Map Kernels  2010
# 8537   Two-Stream RNN/CNN for Action Recognition in 3...  2017
# 18998  SPUDD: Stochastic Planning using Decision Diag...  2013
# ...                                                  ...   ...
# 39090  Image color transfer to evoke different emotio...  2013
# 22460  Fast Mixing Markov Chains for Strongly Rayleig...  2016
# 23014      Nonparametric Quantile-Based Causal Discovery  2018
# 14548  Applying a Hybrid Query Translation Method to ...  2002
# 23787  A Fusion of Labeled-Grid Shape Descriptors wit...  2014
#
#                                                 keywords
# 28178  [adaptation, knowledge, classification, unlabe...
# 32816  [promising, controlling, artificially, corrupt...
# 5153   [introduce, probability, generative, similarit...
# 8537   [recognition, sequences, applications, monitor...
# 18998  [decisions, processes, increasing, theoretic, ...
# ...                                                  ...
# 39090  [framework, different, combinations, different...
# 22460  [probability, functions, constraints, knowledg...
# 23014  [observational, challenging, especially, bivar...
# 14548  [translation, retrieval, dictionaries, transla...
# 23787  [retrieving, challenging, retrieving, effectiv...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 28178    [adaptation, knowledge, classification, unlabe...
# 32816    [promising, controlling, artificially, corrupt...
# 5153     [introduce, probability, generative, similarit...
# 8537     [recognition, sequences, applications, monitor...
# 18998    [decisions, processes, increasing, theoretic, ...
#                                ...
# 2165     [optimization, functions, evaluations, expensi...
# 11020    [statistical, analyzing, reporting, restricted...
# 21909    [reciprocating, interactions, represent, excha...
# 3589     [dictionary, component, fundamental, represent...
# 20171    [determining, alternatives, selection, impreci...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8824 words.
# Out of those 4595 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f7a101e9-b225-469a-9466-04d93b25e13e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7a101e9-b225-469a-9466-04d93b25e13e")) {                    Plotly.newPlot(                        "f7a101e9-b225-469a-9466-04d93b25e13e",                        [{"x":["performing","iterative","distribution","algorithm","extensive","geometric","experiments","distributions","knowledge","discriminative","multiplier","outperforms","optimization","unlabeled","constraints","structures","incorporates","discrepancy","alternating","classification","benchmarks","particular","structure","adaptation","segmentation","nonparametric","effectiveness","alignment","representation","augmented","consistently","generalized","approaches","significantly","supervised","analytically","representations","expansion","augmentation","connection","exploring","iteratively","prediction","techniques","successful","nonlinearity","intractable","corrupting","expectation","performance","nonlinear","technique","difference","controlling","algorithms","demonstrate","performed","extension","conjunction","empirical","minimizes","artificially","regression","incorporating","theoretical","promising","continuous","introduce","probabilistic","observation","incorporate","competitive","generalization","generative","properties","probability","similarity","embeddings","generalizes","formulation","regularization","beneficial","comparing","methodologies","distinguish","monitoring","applications","architecture","recurrent","sequences","information","recognition","convolutional","classifies","surveillance","particularly","resulting","significant","stochastic","processes","algebraic","reduction","decisions","traditional","represent","programming","increasing","structured","represented","theoretic","functions","iteration","illustrated","detection","suggested","described","methodology","integration","describes","framework","following","composite","composition","combinatorial","aggregation","independent","exploration","interrelation","utilization","conservation","integrated","numerical","morphological","generations","multicriteria","hierarchical","alternative","assessment","selection","productive","geological","estimates","alternatives","additional","summarize","comprehension","understand","collections","accessing","attention","listening","examination","mechanism","considered","automatically","attractive","utterances","languages","sequential","constructs","multimedia","challenging","therefore","consuming","relationship","difficult","efficient","applicability","experimental","estimator","effective","variables","comparison","dimension","successfully","covariance","directions","computation","effectively","assumptions","computationally","operators","eigendecomposition","reproducing","separately","biological","predictive","libraries","generating","compounds","optimized","inhibitors","generated","molecules","integrates","reinforcement","integrative","computational","clustering","characteristic"],"y":[82,83,214,797,180,70,617,107,382,95,4,249,325,40,148,122,30,12,35,512,111,306,369,61,195,14,213,47,361,31,39,66,420,268,192,15,231,22,27,51,48,32,220,408,60,3,18,4,18,868,61,257,49,15,582,554,131,87,12,152,16,7,109,57,150,120,97,335,169,48,63,113,97,127,225,157,145,82,25,85,85,12,78,15,34,38,429,248,167,102,710,368,363,12,30,80,145,222,140,102,21,117,62,180,120,134,100,96,84,41,239,54,22,359,24,82,67,53,87,548,87,16,22,41,28,139,55,2,10,6,50,93,26,5,2,99,101,47,149,4,4,66,26,119,21,19,56,14,5,180,3,9,105,139,168,21,14,103,69,19,15,272,132,27,75,143,393,34,390,24,239,136,115,64,86,17,36,150,118,63,86,53,1,7,30,35,61,10,112,3,58,2,180,3,34,115,2,305,132,30],"type":"bar"},{"x":["performing","iterative", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4595,), (4595, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7908333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Laplacian</span> <span style=''>Matrix</span> <span style=''>in</span> <span style=''>Smooth</span> <span style=''>Graph</span> <span style=''>Signal</span> <span style='background-color:rgba(0, 255, 0, 0.4085365853658537);'>Representations</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construction</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>meaningful</span> <span style=''>graph</span> <span style=''>plays</span> <span style=''>a</span> <span style=''>crucial</span> <span style=''>role</span> <span style=''>in</span> <span style=''>the</span> <span style=''>success</span> <span style=''>of</span> <span style=''>many</span> <span style=''>graph</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.4085365853658537);'>representations</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>handling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structured</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>especially</span> <span style=''>in</span> <span style=''>the</span> <span style=''>emerging</span> <span style=''>field</span> <span style=''>of</span> <span style=''>graph</span> <span style=''>signal</span> <span style='background-color:rgba(0, 255, 0, 0.42997542997543);'>processing</span> <span style=''>However</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>meaningful</span> <span style=''>graph</span> <span style=''>is</span> <span style=''>not</span> <span style=''>always</span> <span style=''>readily</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style=''>from</span> <span style=''>the</span> <span style=''>data</span> <span style=''>nor</span> <span style=''>easy</span> <span style=''>to</span> <span style=''>define</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>depending</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>domain</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>it</span> <span style=''>is</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>desirable</span> <span style=''>in</span> <span style=''>graph</span> <span style=''>signal</span> <span style='background-color:rgba(0, 255, 0, 0.42997542997543);'>processing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>that</span> <span style=''>a</span> <span style=''>graph</span> <span style=''>is</span> <span style=''>chosen</span> <span style=''>such</span> <span style=''>that</span> <span style=''>the</span> <span style=''>data</span> <span style=''>admit</span> <span style=''>certain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularity</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>smoothness</span> <span style=''>on</span> <span style=''>the</span> <span style=''>graph</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>address</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>graph</span> <span style='background-color:rgba(255, 0, 0, 0.6000000000000001);'>Laplacians</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style=''>learning</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>topologies</span> <span style='' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Universal</span> <span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Completion</span> <br/><br/><span style=''>The</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completion</span> <span style=''>has</span> <span style=''>recently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>a</span> <span style=''>lot</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>leading</span> <span style=''>to</span> <span style=''>several</span> <span style=''>results</span> <span style=''>that</span> <span style=''>offer</span> <span style=''>exact</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>solutions</span> <span style=''>to</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>However</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>do</span> <span style=''>so</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>make</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>quite</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restrictive</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>More</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specifically</span> <span style=''>the</span> <span style=''>methods</span> <span style=''>assume</span> <span style=''>that</span> <span style=''>a)</span> <span style=''>the</span> <span style=''>observed</span> <span style=''>indices</span> <span style=''>are</span> <span style=''>sampled</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uniformly</span> <span style=''>at</span> <span style=''>random</span> <span style=''>and</span> <span style=''>b)</span> <span style=''>for</span> <span style=''>every</span> <span style=''>new</span> <span style=''>matrix</span> <span style=''>the</span> <span style=''>observed</span> <span style=''>indices</span> <span style=''>are</span> <span style=''>sampled</span> <span style=''>afresh</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>address</span> <span style=''>these</span> <span style=''>issues</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>universal</span> <span style=''>recovery</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantee</span> <span style=''>for</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completion</span> <span style=''>that</span> <span style=''>works</span> <span style=''>for</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>sampling</span> <span style=''>schemes</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>if</span> <span style=''>the</span> <span style=''>set</span> <span style=''>of</span> <span style=''>sampled</span> <span style=''>indices</span> <span style=''>come</span> <span style=''>from</span> <span style=''>the</span> <span style=''>edges</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bipartite</span> <span style=''>graph</span> <span style=''>with</span> <span style=''>large</span> <span style=''>spectral</span> <span style=''>gap</span> <span style=''>(ie</span> <span style=''>gap</span> <span style=''>between</span> <span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Sequential</span> <span style='background-color:rgba(255, 0, 0, 0.30303030303030304);'>Randomized</span> <span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.4214876033057851);'>Factorization</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Processes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Predictions</span> <span style=''>and</span> <span style=''>Hyper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequential</span> <span style='background-color:rgba(255, 0, 0, 0.30303030303030304);'>randomized</span> <span style=''>lowrank</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.4214876033057851);'>factorization</span> <span style=''>approach</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.46666666666666656);'>incrementally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predicting</span> <span style=''>values</span> <span style=''>of</span> <span style=''>an</span> <span style=''>unknown</span> <span style=''>function</span> <span style=''>at</span> <span style=''>test</span> <span style=''>points</span> <span style=''>using</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Processes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>It</span> <span style=''>is</span> <span style=''>well</span> <span style=''>known</span> <span style=''>that</span> <span style=''>in</span> <span style=''>the</span> <span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>bottlenecks</span> <span style=''>are</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inversion</span> <span style=''>of</span> <span style=''>the</span> <span style=''>(regularized)</span> <span style=''>kernel</span> <span style=''>matrix</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>hyper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameters</span> <span style=''>defining</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>The</span> <span style=''>main</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>contributions</span> <span style=''>of</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>are</span> <span style=''>two</span> <span style=''>fold</span> <span style=''>First</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.37931034482758624);'>formalize</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>the</span> <span style=''>inverse</span> <span style=''>of</span> <span style=''>the</span> <span style=''>kernel</span> <span style=''>matrix</span> <span style=''>using</span> <span style='background-color:rgba(255, 0, 0, 0.30303030303030304);'>randomized</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.4214876033057851);'>factorization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style=''>FExt</span> <span style=''>Deep</span> <span style=''>Feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Extraction</span> <span style=''>for</span> <span style=''>Vessel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Segmentation</span> <span style=''>and</span> <span style=''>Centerline</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Prediction</span> <br/><br/><span style=''>Feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extraction</span> <span style=''>is</span> <span style=''>a</span> <span style=''>very</span> <span style=''>crucial</span> <span style=''>task</span> <span style=''>in</span> <span style=''>image</span> <span style=''>and</span> <span style=''>pixel</span> <span style=''>(voxel)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>biomedical</span> <span style=''>image</span> <span style=''>modeling</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>based</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extraction</span> <span style=''>scheme</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inception</span> <span style=''>models</span> <span style=''>for</span> <span style=''>pixel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>tasks</span> <span style=''>We</span> <span style=''>extract</span> <span style=''>features</span> <span style=''>under</span> <span style=''>multi</span> <span style=''>scale</span> <span style=''>and</span> <span style=''>multi</span> <span style=''>layer</span> <span style=''>schemes</span> <span style=''>through</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>operators</span> <span style=''>Layers</span> <span style=''>of</span> <span style=''>Fully</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Convolutional</span> <span style=''>Network</span> <span style=''>are</span> <span style=''>later</span> <span style=''>stacked</span> <span style=''>on</span> <span style=''>this</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extraction</span> <span style=''>layers</span> <span style=''>and</span> <span style=''>trained</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>for</span> <span style=''>the</span> <span style=''>purpose</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>We</span> <span style=''>test</span> <span style=''>our</span> <span style=''>model</span> <span style=''>on</span> <span style=''>the</span> <span style=''>DRIVE</span> <span style=''>and</span> <span style=''>STARE</span> <span style=''>public</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>for</span> <span style=''>the</span> <span style=''>purpose</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>segmentation</span> <span style=''>and</span> <span style=''>centerline</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>and</span> <span style=''>it</span> <span style=''>out</span> <span style=''>performs</span> <span style=''>most</span> <span style=''>existing</span> <span style=''>hand</span> <span style=''>crafted</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>determinist ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.12815051473198438)
# 	architecture (0.08803691870784522)
# 	segmentation (0.06922257720979766)
# 	experimental (0.13844515441959532)
# 	knowledge (0.13560525381611643)
# 	different (0.25168619098331557)
# 	information (0.25204117855875047)
# 	detection (0.12744053958111465)
# 	convolutional (0.1288604898828541)
# 	recognition (0.1306354277600284)
#
# Some Statistics words are:
# 	statistical (0.15330307614725164)
# 	stochastic (0.14523449319213314)
# 	variables (0.14473020675743822)
# 	theoretical (0.15532022188603126)
# 	estimation (0.17650025214321735)
# 	algorithm (0.3908219868885527)
# 	dimensional (0.1815431164901664)
# 	distribution (0.19314170448814927)
# 	regression (0.172970247100353)
# 	inference (0.20776601109430157)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2e33b618-911e-4f7e-98ed-709941fd1756" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e33b618-911e-4f7e-98ed-709941fd1756")) {                    Plotly.newPlot(                        "2e33b618-911e-4f7e-98ed-709941fd1756",                        [{"x":["performing","iterative","distribution","algorithm","extensive","geometric","experiments","distributions","knowledge","discriminative","multiplier","outperforms","optimization","unlabeled","constraints","structures","incorporates","discrepancy","alternating","classification","benchmarks","particular","structure","adaptation","segmentation","nonparametric","effectiveness","alignment","representation","augmented","consistently","generalized","approaches","significantly","supervised","analytically","representations","expansion","augmentation","connection","exploring","iteratively","prediction","techniques","successful","nonlinearity","intractable","corrupting","expectation","performance","nonlinear","technique","difference","controlling","algorithms","demonstrate","performed","extension","conjunction","empirical","minimizes","artificially","regression","incorporating","theoretical","promising","continuous","introduce","probabilistic","observation","incorporate","competitive","generalization","generative","properties","probability","similarity","embeddings","generalizes","formulation","regularization","beneficial","comparing","methodologies","distinguish","monitoring","applications","architecture","recurrent","sequences","information","recognition","convolutional","classifies","surveillance","particularly","resulting","significant","stochastic","processes","algebraic","reduction","decisions","traditional","represent","programming","increasing","structured","represented","theoretic","functions","iteration","illustrated","detection","suggested","described","methodology","integration","describes","framework","following","composite","composition","combinatorial","aggregation","independent","exploration","interrelation","utilization","conservation","integrated","numerical","morphological","generations","multicriteria","hierarchical","alternative","assessment","selection","productive","geological","estimates","alternatives","additional","summarize","comprehension","understand","collections","accessing","attention","listening","examination","mechanism","considered","automatically","attractive","utterances","languages","sequential","constructs","multimedia","challenging","therefore","consuming","relationship","difficult","efficient","applicability","experimental","estimator","effective","variables","comparison","dimension","successfully","covariance","directions","computation","effectively","assumptions","computationally","operators","eigendecomposition","reproducing","separately","biological","predictive","libraries","generating","compounds","optimized","inhibitors","generated","molecules","integrates","reinforcement","integrative","computational","clustering","characteristic","functional","simulation","estimated","procedure","densities","restrictions","stationary","identification","physically","computing","consequently","triangulation","potential","parametric","tessellation","relatively","generally","insensitive","parameter","demonstrates","positively","superiority","approximators","thousands","technology","indicates","feedforward","extremely","connections","including","parameters","conventional","calculate","universal","according","homogeneity","investigate","hypothesis","consistency","artificial","statistics","verification","discriminant","asymptotic","determines","variational","expressive","approximations","graphical","approximate","dependencies","complexity","partially","in ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	metabolic
# 	advantageously
# 	frequentist
# 	collinearity
# 	regularised
# 	straggler
# 	stragglers
# 	imperceptible
# 	factorisation
# 	lancaster
# 	quantiles
# 	geostatistical
# 	sufficiency
# 	checkable
# 	staleness
# 	ergodicity
# 	econometrics
# 	nucleotide
# 	guideline
# 	robustification
# Some words which never appear in Statistics papers:
# 	interrelation
# 	multicriteria
# 	productive
# 	listening
# 	inhibitors
# 	communicated
# 	francisco
# 	genericity
# 	articulated
# 	disparity
# 	pressures
# 	organising
# 	achievements
# 	realworld
# 	prerequisite
# 	reflections
# 	installation
# 	cascading
# 	enriching
# 	subtitles

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.052037234854266e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7533333333333333
